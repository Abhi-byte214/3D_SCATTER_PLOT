# %%
import numpy as np
import json

# %%
np.random.seed(42)
points=1000

# %%
x=np.random.uniform(-200,200,points)
y=np.random.uniform(-400,400,points)
z=np.random.uniform(-100,200,points)
print(x[:3])
print(y[:9])
print(z[2:8])
# Out:
# [-50.18395246 180.28572256  92.79757672]
# [-251.89365693   33.5207579   298.3566687   185.77990913  245.24891829
#   127.02669337  153.82125161  279.35652125 -200.26559291]
# [171.87637416 -25.13614005 -18.41508216 127.81947873  34.92195274
#  133.01316709]

# %%
total=[]
for g in range(points):
    total.append({"x":float(x[g]),"y":float(y[g]),"z":float(z[g])})

# %%
print(total[:4])
# Out:
# [{'x': -50.183952461055014, 'y': -251.89365692910428, 'z': -21.488294879228206}, {'x': 180.2857225639665, 'y': 33.52075790268651, 'z': -25.906360278400058}, {'x': 92.79757672456202, 'y': 298.35666870112664, 'z': 171.876374156311}, {'x': 39.46339367881464, 'y': 185.77990912764892, 'z': -25.136140045148167}]

# %%
with open("Data.json","w")
# Out:
#   Cell In[6], line 1
#     with open("Data.json","w")
#                               ^
# SyntaxError: expected ':'
